# %% [markdown]
# Basic Python
# ----
#
# - Appropriate use of data structures
# - Write a function
# - Higher order functions
# - Equivalents of for-loops
# - Basic string processing
# - Importing packages
# - Read and write to file
#
# Scientific computation
# ----
#
# - Symbolic algebra with `sympy` e.g. perform integration
# - Working with `numpy` vectors and arrays
# - Using `scipy.linalg` routines
# - Graphing in `matplotlib` and `seaborn`
# - Split-apply-combine with `pandas` Series and DataFrames
# - Finding roots and minima with `scipy.optimize`
# - Pre-processing, unsupervised and supervised learning with `sklearn`
#
# Linear Algebra
# ----
#
# - Linear combinations and independence
# - Change of basis and similar matrices
# - $A = LU$ (Gaussian elimination)
# - $A = LL^T$ (Symmetry)
# - $A = QR$ (Orthogonality)
# - $A = S\Lambda S^{-1}$ (Eigenvalues and eigenvectors)
# - $A = Q\Lambda Q^T$ (Diagonalization of symmetric matrix)
# - $A = U\Sigma V^T$ (Singular values)
# - Positive definite matrices
# - $A^TA\hat{x} = A^Tb$ (Projection and least squares)
#
# Calculus
# ----
#
# - Evaluating critical points
# - Taylor series
# - Gradient, Jacobian and Hessian
# - Calculating conjugate gradients
# - Newton method (univariate and multivariate)
# - Gradient descent (batch and stochastic)
# - Lagrange multipliers for constrained problems
#
# EM
# ----
#
# - Likelihood and log-likelihood
# - Jensen's inequality
# - Basic concept of the EM algorithm
# - K-means algorithm
#
# Random numbers
# ----
#
# - Inverse transform method
# - Familiar with  probability distributions from `numpy.random` and `scipy.stats`
# - How to calculate quantiles, PDF and CDF and other statistics of a random variable
#
# Resampling and Monte Carlo simulations
# ----
#
# - Bootstrap
# - Leave-one out calculations (including LOOCV)
# - Empirical CDF and kernel density estimation
#
# Numerical integration
# ----
#
# - Quadrature with `scipy.integrate` methods
# - Why Monte Carlo integration works
# - Change of variables
# - Importance sampler
# - Other Monte Carlo swindles
#
# Markov Chain Monte Carlo
# ----
#
# - Working with Markov matrices (linear algebra revisited)
# - Conditions for convergence to equilibrium distribution
# - Detailed balance
# - How they work
#   - Random walk sampler
#   - Gibbs sampler
#   - Slice sampler
#   - HMC sampler
# - Use of PyMC3 and PyStan to fit simple hierarchical models
